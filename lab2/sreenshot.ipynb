# %% [markdown]
# ## Bài 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Bài 2
#
# ### Tần số xuất hiện của các từ trên 500 lần.
# ![image.png](attachment:image.png)
#
# ### Số bình luận theo từng phân loại
# ![image-2.png](attachment:image-2.png)
#
# ### số bình luận theo từng khía cạnh đánh giá
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Bài 3
#
# ### Khía cạnh nhiều đánh giá tiêu cực (negative) nhất và khía cạnh nhận nhiều đánh giá tích cực nhất (positive) nhất.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Bài 4
#
# ### **5 từ** từ mang ý nghĩa tích cực nhất trên từng loại bình luận
# ![image.png](attachment:image.png)
#
# ### **5 từ** từ mang ý nghĩa tiêu cực nhất trên từng loại bình luận
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Bài 5
#
# ![image.png](attachment:image.png)
